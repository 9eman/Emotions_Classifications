# %%
import pandas as pd
import os
import glob as gb
from tensorflow import keras

from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense

# %%
TRAIN_DIR = "C:\\Users\\almon\\Desktop\\ee\\eINTERFACE_2021_Image\\train\\"
TEST_DIR = "C:\\Users\\almon\\Desktop\\ee\\eINTERFACE_2021_Image\\test\\"
BATCH_SIZE=64

# %%
for folder in os.listdir(TRAIN_DIR):
    files = gb.glob(pathname= str(TRAIN_DIR+ '/'+ folder + '/*.jpg'))
    print(f'For training data, found {len(files)} in folder {folder}')
# Out:
# For training data, found 1896 in folder Anger
# For training data, found 1891 in folder Disgust
# For training data, found 1922 in folder Fear
# For training data, found 1922 in folder Happiness
# For training data, found 1922 in folder Sadness
# For training data, found 1922 in folder Surprise

# %%
for folder in os.listdir(TEST_DIR):
    files = gb.glob(pathname= str(TEST_DIR+ '/'+ folder + '/*.jpg'))
    print(f'For testing data, found {len(files)} in folder {folder}')
# Out:
# For testing data, found 237 in folder Anger
# For testing data, found 237 in folder Disgust
# For testing data, found 241 in folder Fear
# For testing data, found 241 in folder Happiness
# For testing data, found 241 in folder Sadness
# For testing data, found 241 in folder Surprise

# %%
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def view_random_image(target_dir, target_class):
    # We will view images from here
    target_folder = target_dir + target_class
    
    # Get a random image path
    random_image = random.sample(os.listdir(target_folder), 1)
    
    # read in the image and plot it using matplolib
    img = mpimg.imread(target_folder+'/'+random_image[0])
    plt.imshow(img)
    plt.title(target_class)
    plt.axis('off')
    print(f"Image shape {img.shape}")
    
    return img

# %%
class_names = ['Anger','Disgust','Fear','Happiness','Sadness','Surprise']

# %%
plt.figure(figsize=(20,10))
for i in range(18):
    plt.subplot(3, 6, i+1)
    class_name = random.choice(class_names)
    img = view_random_image(target_dir="C:\\Users\\almon\\Desktop\\ee\\eINTERFACE_2021_Image\\train\\", target_class=class_name)
# Out:
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory(TRAIN_DIR,
                                                 target_size = (128, 128),
                                                 batch_size = BATCH_SIZE,
                                                 class_mode = 'categorical')

test_set = test_datagen.flow_from_directory(TEST_DIR,
                                            target_size = (128, 128),
                                            batch_size = BATCH_SIZE,
                                            class_mode = 'categorical')
# Out:
# Found 11475 images belonging to 6 classes.
# Found 1438 images belonging to 6 classes.

# %%
# Initialising the CNN
classifier = Sequential()

# Step 1 - Convolution
classifier.add(Conv2D(16, (3, 3), input_shape = (128, 128, 3), activation = 'relu'))

# Step 2 - Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Adding a second convolutional layer
classifier.add(Conv2D(32, (3, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))



# Step 3 - Flattening
classifier.add(Flatten())

# Step 4 - Full connection
classifier.add(Dense(units = 128, activation = 'relu'))

classifier.add(Dense(units = 6, activation = 'softmax'))

# Compiling the CNN
classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
## model summary
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 28800)             0
#
#  dense (Dense)               (None, 128)               3686528
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 3,692,390
# Trainable params: 3,692,390
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = classifier.fit(training_set,
                         epochs = 50,
                         validation_data = test_set)


classifier.save('model1.h5')  # creates a HDF5 file 'my_model.h5'
# Out:
# Epoch 1/50
# 180/180 [==============================] - 71s 393ms/step - loss: 1.8284 - accuracy: 0.2428 - val_loss: 1.6819 - val_accuracy: 0.3122
# Epoch 2/50
# 180/180 [==============================] - 70s 388ms/step - loss: 1.5912 - accuracy: 0.3452 - val_loss: 1.6268 - val_accuracy: 0.3442
# Epoch 3/50
# 180/180 [==============================] - 70s 388ms/step - loss: 1.4522 - accuracy: 0.4122 - val_loss: 1.3492 - val_accuracy: 0.4562
# Epoch 4/50
# 180/180 [==============================] - 71s 396ms/step - loss: 1.3247 - accuracy: 0.4718 - val_loss: 1.2724 - val_accuracy: 0.4896
# Epoch 5/50
# 180/180 [==============================] - 71s 397ms/step - loss: 1.2300 - accuracy: 0.5161 - val_loss: 1.2164 - val_accuracy: 0.5257
# Epoch 6/50
# 180/180 [==============================] - 71s 395ms/step - loss: 1.1454 - accuracy: 0.5582 - val_loss: 1.1599 - val_accuracy: 0.5542
# Epoch 7/50
# 180/180 [==============================] - 72s 400ms/step - loss: 1.0603 - accuracy: 0.5902 - val_loss: 0.9804 - val_accuracy: 0.6231
# Epoch 8/50
# 180/180 [==============================] - 71s 392ms/step - loss: 0
50
# 180/180 [==============================] - 71s 392ms/step - loss: 0.5096 - accuracy: 0.8127 - val_loss: 0.5500 - val_accuracy: 0.7942
# Epoch 31/50
# 180/180 [==============================] - 71s 395ms/step - loss: 0.5033 - accuracy: 0.8189 - val_loss: 0.6435 - val_accuracy: 0.7726
# Epoch 32/50
# 180/180 [==============================] - 72s 397ms/step - loss: 0.5088 - accuracy: 0.8110 - val_loss: 0.7091 - val_accuracy: 0.7524
# Epoch 33/50
# 180/180 [==============================] - 71s 392ms/step - loss: 0.4890 - accuracy: 0.8226 - val_loss: 0.6203 - val_accuracy: 0.7733
# Epoch 34/50
# 180/180 [==============================] - 72s 398ms/step - loss: 0.4818 - accuracy: 0.8253 - val_loss: 0.6490 - val_accuracy: 0.7775
# Epoch 35/50
# 180/180 [==============================] - 70s 389ms/step - loss: 0.4672 - accuracy: 0.8328 - val_loss: 0.5652 - val_accuracy: 0.7955
# Epoch 36/50
# 180/180 [==============================] - 71s 393ms/step - loss: 0.4539 - accuracy: 0.8347 - val_loss: 0.5721 - val_accuracy: 0.7914
# Epoch 37/50
# 180/180 [==============================] - 72s 400ms/step - loss: 0.4523 - accuracy: 0.8338 - val_loss: 0.5562 - val_accuracy: 0.7942
# Epoch 38/50
# 180/180 [==============================] - 71s 394ms/step - loss: 0.4537 - accuracy: 0.8305 - val_loss: 0.5413 - val_accuracy: 0.8004
# Epoch 39/50
# 180/180 [==============================] - 71s 395ms/step - loss: 0.4400 - accuracy: 0.8407 - val_loss: 0.5385 - val_accuracy: 0.8011
# Epoch 40/50
# 180/180 [==============================] - 71s 392ms/step - loss: 0.4366 - accuracy: 0.8406 - val_loss: 0.5142 - val_accuracy: 0.8178
# Epoch 41/50
# 180/180 [==============================] - 72s 397ms/step - loss: 0.4260 - accuracy: 0.8462 - val_loss: 0.4666 - val_accuracy: 0.8289
# Epoch 42/50
# 180/180 [==============================] - 71s 392ms/step - loss: 0.4153 - accuracy: 0.8526 - val_loss: 0.5353 - val_accuracy: 0.8025
# Epoch 43/50
# 180/180 [==============================] - 72s 397ms/step - loss: 0.4071 - accuracy: 0.8519 - val_loss: 0.5686 - val_accuracy: 0.7997
# Epoch 44/50
# 180/180 [==============================] - 72s 401ms/step - loss: 0.3980 - accuracy: 0.8590 - val_loss: 0.5780 - val_accuracy: 0.7976
# Epoch 45/50
# 180/180 [==============================] - 70s 390ms/step - loss: 0.4034 - accuracy: 0.8538 - val_loss: 0.5303 - val_accuracy: 0.8178
# Epoch 46/50
# 180/180 [==============================] - 70s 389ms/step - loss: 0.4119 - accuracy: 0.8525 - val_loss: 0.5750 - val_accuracy: 0.7969
# Epoch 47/50
# 180/180 [==============================] - 70s 390ms/step - loss: 0.3914 - accuracy: 0.8558 - val_loss: 0.5706 - val_accuracy: 0.7942
# Epoch 48/50
# 180/180 [==============================] - 72s 397ms/step - loss: 0.4074 - accuracy: 0.8514 - val_loss: 0.6498 - val_accuracy: 0.7830
# Epoch 49/50
# 180/180 [==============================] - 72s 398ms/step - loss: 0.3909 - accuracy: 0.8645 - val_loss: 0.5497 - val_accuracy: 0.8060
# Epoch 50/50
# 180/180 [==============================] - 71s 394ms/step - loss: 0.3734 - accuracy: 0.8659 - val_loss: 0.6477 - val_accuracy: 0.7768

# %%
classifier.evaluate(test_set)
# Out:
# 23/23 [==============================] - 3s 144ms/step - loss: 0.6477 - accuracy: 0.7768
# [0.647657573223114, 0.7767732739448547]

# %%
pd.DataFrame(history.history)[['loss','val_loss']].plot()
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
pd.DataFrame(history.history)[['accuracy','val_accuracy']].plot()
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
training_set.class_indices
# Out:
# {'Anger': 0,
#  'Disgust': 1,
#  'Fear': 2,
#  'Happiness': 3,
#  'Sadness': 4,
#  'Surprise': 5}
